# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

# %%
#agriculture heatmap
def readdata(filename):
   
    file = pd.read_csv(filename)
    return file

dt = readdata('agricultural land.csv')
dt.head()
data =dt.pivot_table(index ="Country Name",columns = "Indicator Name",values=['1990','1991','1992','1993','1994'])
d=data.head(8)
d
plt.figure(figsize=(6,4))
plt.title('agricultural heatmap')
sns.heatmap(data = d, annot = True,fmt='.0f')
# Out:
# <AxesSubplot:title={'center':'agricultural heatmap'}, xlabel='None-Indicator Name', ylabel='Country Name'>

# %%
#energy consumption heat map
dt = readdata('energy consuption.csv')
data =dt.pivot_table(index = "Country Name",columns = "Indicator Name",values=['2014','2015','2017','2019'])
d=data.head(8)
d
plt.figure(figsize=(9,5))
plt.title("energy graph")
sns.heatmap(data = d, annot = True)
# Out:
# <AxesSubplot:title={'center':'energy graph'}, xlabel='None-Indicator Name', ylabel='Country Name'>

# %%
#arabal land heatmap
dt = readdata('Arabal land.csv')
data =dt.pivot_table(index ="Country Name",columns = "Indicator Name",values=['1990','1991','1992','1993','1994'])
d=data.head(8)
d
plt.figure(figsize=(7,4))
plt.title("arabal land")
sns.heatmap(data = d, annot = True,cmap= 'mako')
# Out:
# <AxesSubplot:title={'center':'arabal land'}, xlabel='None-Indicator Name', ylabel='Country Name'>

# %%
#Arabal land chart
def readdta(filename):
      file = pd.read_csv(filename , usecols=['1961','1962','1963','1964','1965','1966'])
      return file

dt = readdta("C:\\Users\\HANZALLAH\\OneDrive\\Desktop\\Arabal land.csv")
colummns = ['Aruba','Africa Eastern and Southern','Afghanistan', 'Africa Western and Central','Angola','Albania']
fi = pd.read_csv("C:\\Users\\HANZALLAH\\OneDrive\\Desktop\\Arabal land.csv")
c_nm = fi['Country Name']
data_frame = pd.DataFrame(dt.head(6))
trans = data_frame.T
trans.columns = c_nm.head(6)
trans
country_names = c_nm.head(6)
years_values = trans.head(6)
years_values
years = list(years_values)
years
first = trans.loc[:,"Aruba"]
second = trans.loc[:,"Africa Eastern and Southern"]
third = trans.loc[:,"Afghanistan"]
fourth = trans.loc[:,"Africa Western and Central"]
fifth = trans.loc[:,"Angola"]
sixth = trans.loc[:,"Albania"]
x = years
y1 = first
y2 = second

fig, ax1 = plt.subplots()
plt.xticks(rotation=90)

ax2 = ax1.twinx()
ax1.plot(x, y1, 'g-',linestyle = ':',label="1961")
ax2.plot(x, y2, 'b-',label="1962")
ax2.spines['left'].set_position(('outward',40))

ax3 = ax2.twinx()
ax3.plot(x,third,'r-',linestyle = ':',label="1963")
ax3.spines['left'].set_position(('outward',60))

ax4 = ax3.twinx()
ax4.plot(x,fourth,color = 'yellow',label="1964")
ax4.spines['left'].set_position(('outward',80))

ax5 = ax4.twinx()
ax5.plot(x,fifth,color="brown",linestyle = ':', label="1965")
ax5.spines['left'].set_position(('outward',100))

ax6 = ax5.twinx()
ax6.plot(x,sixth,color="black", label="1966")

ax1.set_xlabel('years')
ax1.set_ylabel('value')
ax6.set_ylabel('value')
plt.xticks(rotation = 190)
plt.title('arabal land')
plt.show()
# Out:
# C:\Users\HANZALLAH\AppData\Local\Temp\ipykernel_11636\27432842.py:33: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "g-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'g-',linestyle = ':',label="1961")
# C:\Users\HANZALLAH\AppData\Local\Temp\ipykernel_11636\27432842.py:38: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax3.plot(x,third,'r-',linestyle = ':',label="1963")

# %%
#agricultureland chart
dt = readdta("agricultural land.csv")
colummns = ['Aruba','Africa Eastern and Southern','Afghanistan', 'Africa Western and Central','Angola','Albania']
fi = pd.read_csv("Arabal land.csv")
c_nnm = fi['Country Name']
data_frame = pd.DataFrame(dt.head(6))
trans = data_frame.T
trans.columns = c_nnm.head(6)
trans
country_names = c_nnm.head(6)
years_values = trans.head(6)
years_values
years = list(years_values)
years
first = trans.loc[:,"Aruba"]
second = trans.loc[:,"Africa Eastern and Southern"]
third = trans.loc[:,"Afghanistan"]
fourth = trans.loc[:,"Africa Western and Central"]
fifth = trans.loc[:,"Angola"]
sixth = trans.loc[:,"Albania"]
x = years
y1 = first
y2 = second
fig, ax1 = plt.subplots()
plt.xticks(rotation=90)

ax2 = ax1.twinx()
ax1.plot(x, y1, 'g-',linestyle = ':',label="1961")
ax2.plot(x, y2, 'b-',linestyle = ':',label="1962")
ax2.spines['left'].set_position(('outward',40))

ax3 = ax2.twinx()
ax3.plot(x,third,'r-',label="1963")
ax3.spines['left'].set_position(('outward',80))

ax4 = ax3.twinx()
ax4.plot(x,fourth,color = 'yellow',linestyle = ':',label="1964")
ax4.spines['left'].set_position(('outward',190))

ax5 = ax4.twinx()
ax5.plot(x,fifth,color="brown",linestyle = ':', label="1965")
ax5.spines['left'].set_position(('outward',120))

ax6 = ax5.twinx()
ax6.plot(x,sixth,color="black",linestyle = ':', label="1966")

ax1.set_xlabel('years')
ax1.set_ylabel('value')
ax6.set_ylabel('value')
plt.title("agricultural land")
plt.show()
# Out:
# C:\Users\HANZALLAH\AppData\Local\Temp\ipykernel_11636\211885935.py:28: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "g-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.plot(x, y1, 'g-',linestyle = ':',label="1961")
# C:\Users\HANZALLAH\AppData\Local\Temp\ipykernel_11636\211885935.py:29: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax2.plot(x, y2, 'b-',linestyle = ':',label="1962")

# %%
#energy consuption chart
def readata(filename):
    file = pd.read_csv(filename,usecols=['2021','Country Name','Indicator Name'])
    return file.head(5)
df = readata('C:\\Users\\HANZALLAH\\OneDrive\\Desktop\\energy consuption.csv')
df.pivot(index='Country Name',columns='Indicator Name',values='2021').plot(kind='bar',figsize = (15,8),width = 0.7)
plt.title('engergy consuption')
plt.ylabel('energy consumed')
# Out:
# Text(0, 0.5, 'energy consumed')

# %%
#arabal populTION chart
def readdata(filename):
   
    file = pd.read_csv(filename,usecols=['2021','Country Name','Indicator Name'])
    return file

dt = readdata("arabal population.csv")
dt.pivot(index='Country Name',columns='Indicator Name',values='2021').plot(kind='bar',figsize = (15,8),width = 0.7)
plt.title('population increase')
plt.ylabel('val')
# Out:
# Text(0, 0.5, 'val')
